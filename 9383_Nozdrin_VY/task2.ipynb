# %% [markdown]
# # Практическая работа №2: Исследование задач о раскрасках
#
# Выполнил студент гр. 9383 Ноздрин Василий, **вариант 102 (932021)**.

# %% [markdown]
# ## Цель работы
#
# Формирование представления о задачах о раскрасках, выработать умение использование леммы Бёрнсайда для решения задачи о раскрасках, привить навык использования систем компьютерной алгебры для реализации алгоритмов решения задачи.

# %% [markdown]
# ## Содержание блокнота
#
# 1. Цель работы.
# 2. Основные теоретические положения.
# 3. Постановка задачи с кратким описанием выполнения работы.
# 4. Аналитическое решение задачи с соответствующими комментариями.
# 5. Реализация функции отображения раскраски по заданному номеру.
# 6. Общий вывод по проделанной работе.

# %% [markdown]
# ## Основные теоретические положения
#
# **Постановка задачи:** Круг разбит на $154$ сектора, каждый из которых покращен в один из $6$ цветов. Сколькими способами можно составить такую мозаику (с точностью до поворотов круга)?

# %% [markdown]
# ### Определение
#
# Пусть $G$ - группа с нейтральным элементом $e$, и $X$ - некоторое множество.
# Говорят, что $G$ действует на $X$, если задана операция $G\times X\to G$
# Со следующими свойствами:
# 1. $\forall x\in X:\quad ex=x$
# 2. $\forall x\in X,\forall g,h\in G:\quad g(hx)=(gh)x$

# %% [markdown]
# ### Определение
#
# Орбитой $x\in X$ по действию группы $G$ на множество $X$ называется множество $Gx = \{gx|g\in G\}$.
#
# Длина орбиты - количество элементов в данной орбите.

# %% [markdown]
# ### Определение
#
# Неподвижными точками элемента $g\in G$ называют те $x\in X$ для которых $gx = x$.
#
# $X^g \quad-$ множество неподвижных точек по элементу $g$

# %% [markdown]
# ### Лемма Бёрнсайда
#
# Количество орбит действия группы $G$ на множестве $X$ равно $\frac{1}{|G|}\sum_{g\in G}|X^g|$

# %% [markdown]
# ### Определение
#
# Пусть $I$ - произвольное множество, и $C$ - множество цветов.
# Раскраской множества $I$ называется функция из $I$ в $C$.
# Множество всех раскрасок обозначается $C^{I}$.
# Количество раскрасок равно ${|C|}^{|I|}$

# %% [markdown]
# ### Определение
#
# Если $G$ - группа, действующая на множестве $I$, тогда для любых $g\in G, i\in I, f \in C^I$
# выражение $gf(i)=f(g^{-1}i)$ задает действие $g$ на $C^I$.

# %% [markdown]
# ### Теорема
#
# Для любого $g\in G$ и любой функции $f \in C^I$ следующие условия эквивалентны:
# 1. $gf=f$
# 2. $\forall i\in I,\forall n\in\mathbb Z\quad f(i)=f(g^ni)$
# 3. $\forall i,j \in I$ если $i, j$ лежат в одном цикле в циклической записи перестановки $\varphi(x)$, то $f(i)=f(j)$. (В терминологии задачи о бусах это означает, что все места из одного цикла покрашены в одинаковый цвет).

# %% [markdown]
# ### Определение
#
# Количество раскрасок $C^I$, которые сохранят данный элемент $g\in G$ равно ${|C|}^{c\varphi(g)}$.
# где $c\varphi$ - количество независимых циклов в перестановке $\varphi$.

# %% [markdown]
# ### Лемма
#
# Предположим, что $\sigma$ является циклом длины $k$, а $НОД(k,n)=d$.
# Тогда перестановка $\sigma^n$ является произведением $d$ циклов длины $k/d$.

# %% [markdown]
# ## Постановка задачи
#
# Аналитически решить задачу о раскрасках; графически отобразить решения задачи с использованием системы компьютерной алгебры SageMath. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Порядок выполнения работы
#
# 1. Аналитически решить задачу о раскрасках для заданного варианта. Все умозаключения в ходе решения обосновать и содержательно проинтерпретировать.
# 2. Реализовать средствами SageMath функцию, отображающую графически раскраску по заданному номеру. Продемонстрировать работу функции на нескольких примерах. Сделать выводы.
# 3. Дополнительное необязательное задание: для заданного варианта решить задачу в общем виде.

# %% [markdown]
# ## Вопросы для самоконтроля
#
# 1. Определение действия группы на множество.
# 2. Определение орбиты.
# 3. Определение неподвижных точек.
# 4. Лемма Бёрнсайда. Доказательство.
# 5. Постановка задачи о раскрасках.
# 6. Определение множества раскрасок.
# 7. Количество раскрасок. Доказательство.

# %% [markdown]
# ## Список литературы:
#
# 1. Степанов А.В. Лемма Бернсайда и задачи о раскрасках. URL: [http://alexei.stepanov.spb.ru/students/algebra3/Bernside.pdf](http://alexei.stepanov.spb.ru/students/algebra3/Bernside.pdf), 2016

# %% [markdown]
# ## Выполнение работы
#
# **Постановка задачи:** Круг разбит на $154$ сектора, каждый из которых покращен в один из $6$ цветов. Сколькими способами можно составить такую мозаику (с точностью до поворотов круга)?

# %% [markdown]
# ### Решение
#
# Рассмотрим $\{a,b,c,d,e,f\}\quad-$ множество цветов, $\{x_1,x_2,x_3\dots,x_{154}\}\quad-$ множество секторов круга, где $\forall i\  x_i \in \{a,b,c,d,e,f\}$. Всего таких мозаик будет $6^{154}$ не учитывая повороты круга.

# %%
import matplotlib.pyplot as plt

size = 154
colours = ['red','orange','yellow','green','cyan','blue']
sizes = [1 for i in range(size)]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, radius=10, normalize=True, startangle=90, colors=colours)

plt.show()

# %% [markdown]
# ## Выводы
#
# В ходе выполнения практической работы был получен опыт решения задач о раскрасках, изучена лемма Бернсайда в рамках рещения задач о раскрасках, а также реализованы алгоритмы с помощью системы компьютерной алгербы. Помимо этого была решена задача о раскрасках аналитическим методом. Реализована функция, отображающая раскраску графически.
