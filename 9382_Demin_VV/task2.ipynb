# %% [markdown]
# ## Практическая работа №2: Исследование задач о раскрасках
# Выполнил студент гр. 9382 Демин Виктор, вариант 71.

# %% [markdown]
# ## Цель работы
# Формирование представления о задачах о раскрасках, выработать умение использование леммы Бёрнсайда для решения задачи о раскрасках, привить навык использования систем компьютерной алгебры для реализации алгоритмов решения задачи.

# %% [markdown]
# ## Основные теоретические положения

# %% [markdown]
# #### 1.
# Пусть $G$ - группа с нейтральным элементом $e$, а $X$ - множество. $G$ действует на $X$, если задана операция $G \times X \to X$, обладающая для $\forall x \in X$ и $\forall g,h \in G$ следующими свойствами:
#
# 1) $ex = x$
#
# 2) $g(hx) = (gh)x$
#
# где $gx$ - это образ пары $(g,x)$.

# %% [markdown]
# #### 2.
# Пусть $X$ - множество. Множество всех биективных функций с $X \to X$ с операцией композиции называется симметрической группой на множестве $X$ и обозначается как $S_{X}$

# %% [markdown]
# #### 3.
# Орбитой элемента $x \in X$ под действием $G$ называется множество $Gx = \{gx | g \in G\}$. Количество элементов в данной орбите называется длиной орбиты. Любые две орбиты либо не пересекаются, либо совпадают. Таким образом, множество $X$ разбивается в дизъюнктивное объединение орбит.

# %% [markdown]
# Неподвижными точками элемента $g \in G$ называются те $x \in X$, для которых $gx = x$. Множество неподвижных точек элемента g обозначается через $X^{g}$.

# %% [markdown]
# ##### Теорема Бёрнсайда
# Количество орбит действия группы $G$ на множестве $X$ равно:
#
# $\frac{1}{|G|}\sum_{g \in G} |X^{g}|$

# %% [markdown]
# ##### Лемма 1
# Предположим, что $\sigma$ является циклом длины $k$, а $НОД(k,n) = d$. Тогда перестановка $\sigma^{n}$ является произведением d циклов длины $\frac{k}{d}$.

# %% [markdown]
# ##### 5.
# Пусть $I$ - произвольное множество, а $C$ - множество цветов. Раскраской множества $I$ называется функция из $I$ в $C$. Множество всех раскрасок обозначается через $C^{I}$.

# %% [markdown]
# ##### Лемма 2
# Пусть $G$ группа, действующая на множестве $I$. Тогда формула $gf(i) = f(g^{-1}i)$, где $g \in G$, $i \in I$, а $f \in C^{I}$ задает действие $G$ на $C^{I}$.

# %% [markdown]
# ##### Лемма 3
# Для элемента $g \in G$ и функции $f \in C^{I}$ следующие условия эквивалентны:
#
# 1)$gf = f$
#
# 2)$f(i) = f(g^{n}i)$, $\forall i \in I $ и $n \in \mathbb{Z}$
#
# 3)Если $i,j \in I$ лежат в одном цикле в циклической записи перестановки $\varphi(g)$, то $f(i) = f(j)$ (в терминологии задачи о бусах, это означает, что все места из одного цикла покрашены в одинаковый цвет)

# %% [markdown]
# #### Следствие 1
#
# Количество раскрасок из $C^{I}$, которые сохраняет данный элемент $g \in G$ равно $|C^{c(\varphi(g))}|$, где $c(\varphi(g))$ - количество независимых циклов перестановки $\varphi(g)$ (считая циклы длины 1).

# %% [markdown]
# ## Постановка задачи
# Аналитически решить задачу о раскрасках; графически отобразить решения задачи с использованием системы компьютерной алгебры SageMath. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Порядок выполнения работы
# 1. Аналитически решить задачу о раскрасках для заданного варианта. Все умозаключения в ходе решения обосновать и содержательно проинтерпретировать.
#
# 2. Реализовать средствами SageMath функцию, отображающую графически раскраску по заданному номеру. Продемонстрировать работу функции на нескольких примерах. Сделать выводы.
#
# 3. Дополнительное необязательное задание: для заданного варианта решить задачу в общем виде.

# %% [markdown]
# ## Выполнение работы

# %% [markdown]
# ### 1. Аналитическое решение

# %% [markdown]
# Круг разбит на 99 секторов каждый из которых покрашен в одиз из 3 цветов. Сколькими способами можно составить такую мозайку (с точностью до поворотов круга)?

# %% [markdown]
# По условию дано $\{ x_{1}, x_{2}, x_{3}, ... , x_{99} \}$ ,где $x_{i} \in \{ 1, 2, 3\}$. $x_{i}$ - один из трех цветов.
# Общее количество перестановок равно $4^99$. Но например для наборов $\{ x_{1}, x_{2}, x_{3}, ... , x_{99} \}$ и $\{  x_{99}, x_{1}, x_{2}, x_{3}, ... , x_{98} \}$ будут представлять одинаковые круги. Значит, операция поворота не будет давать новые круги.

# %% [markdown]
# На множестве всех раскрасок $X$ действует группа поворотов. Обозначим эту группу как $G$. Операция в группе является композиций, она является ассоциативной, нейтральный элемент - тождественное отображение $id(x)=x$, обратный элемент к повороту - поворот в другую сторону.

# %% [markdown]
# Зададим отображение из $G$ в симметрическую группу $S_{77}$, так как $G$ действует на множество мест $\{1, 2, 3, ..., 99\}$.

# %% [markdown]
# Обозначим $\tau$ - как операцию поворота.

# %% [markdown]
# Тогда группа $G$ состоит из {$e$,$\tau$,$\tau^2$,..,$\tau^{98}$}

# %% [markdown]
# По определению любые две орбиты либо не пересекаются, либо совпадают. Значит количество различных кругов совпадает с количеством различных орбит. Тогда воспользовавшись теоремой Бёрнсайда и следствием 1 мы сможем найти это количетсво.

# %% [markdown]
# Для этого необходимо узнать количество циклов в каждой перестановке полученной под действием элементов группы $G$. Для этого воспользуемся леммой 1.
# "Предположим, что $\sigma$ является циклом длины $k$, а $НОД(k,n) = d$. Тогда перестановка $\sigma^{n}$ является произведением d циклов длины $\frac{k}{d}$."

# %% [markdown]
# Очевидно, $k=99$ - это произведение $3$,$3$ и $11$. Тогда, чтобы d было не равно 1. n - должно иметь множитель 3,9,или 11,то есть при %n\in \{3, 6, 9, 11, 12, 15, 18, 21, 22, 24, 27, 30, 33, 36, 39, 42, 44, 45, 48, 51, 54, 55, 57, 60, 63, 66, 69, 72, 75, 77, 78, 81, 84, 87, 88, 90, 93, 96}

# %% [markdown]
# $\#X^{e} = 3^{99}$
#
# $\#X^{\tau^{i}} = 3^{1}$, где $i \in \{1..98\} / \{ i | (i\%3 = 0) || (i\%11 = 0)\}$
#
# $\#X^{\tau^{i}} =3^3$, при $i \in \{3, 6, 12, 15, 21, 24, 30, 39, 42, 48, 51, 57, 60, 69, 75, 78, 84, 87, 93, 96\}$
#
# $\#X^{\tau^{i}} =3^9$, при $i \in \{9,18,27,36,45,54,63,72,81,90\}$
#
# $\#X^{\tau^{i}} =3^{11}$, при $i \in \{11,22,44,55,77,88\}$
#
# $\#X^{\tau^{i}} =3^{33}$, при $i \in \{33,66\}$
#
# $\#G = 99$

# %% [markdown]
# Ответ:$\frac{1}{99}(3^{99} + 60*3^{1}+ 20*3^3 + 10*3^{9} + 6*3^{11} + 2*3^{33}) = 1735277847582529734129498753419712549042123355$

# %% [markdown]
# ### 2.Графическое представление

# %%
import random
permutations = [[i,random.randint(1,3)] for i in range(1,100)]

# %%
def rotate(permutations):
    return [permutations[-1]] + permutations[:-1]

# %%
import matplotlib
from matplotlib.patches import Wedge
import matplotlib.pyplot as plt

# %%
def printCircle(temp):
    fig=plt.figure(figsize=(12, 12))
    ax=fig.add_subplot(111) 
    plt.axis([-1, 1, -1, 1])
    color_dict = {1 : 'red', 2 : 'green', 3 : 'blue'}

    dx=360/len(temp)
    print(dx)
    for i in range(0,len(temp)):
        fov1 = Wedge((0,0), 1, i*dx, i*dx+0.1,color='black')
        fov2 = Wedge((0,0), 1, i*dx+dx-0.1, i*dx+dx,color='black')

        fov = Wedge((0,0), 1, i*dx, i*dx+dx,color=color_dict[temp[i][1]])
        ax.add_artist(fov)
        ax.add_artist(fov1)
        ax.add_artist(fov2)

        

    plt.show()

# %%
printCircle(permutations)
# Out:
# 40/11

# %%
temp=permutations
temp=rotate(temp)
printCircle(temp)
# Out:
# 40/11

# %%
temp=permutations
for i in range(20):
    temp=rotate(temp)
printCircle(temp)
# Out:
# 40/11

# %%
temp=permutations
for i in range(99):
    temp=rotate(temp)
printCircle(temp)
# Out:
# 40/11
