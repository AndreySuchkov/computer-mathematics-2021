# %% [markdown]
# # Практическая работа №2: Исследование задач о раскрасках

# %% [markdown]
# Выполнил студент группы 9382 Рыжих Роман, вариант 82.

# %% [markdown]
# ## Цель работы

# %% [markdown]
# Формирование представления о задачах о раскрасках, выработать умение использование леммы Бёрнсайда для решения задачи о раскрасках, привить навык использования систем компьютерной алгебры для реализации алгоритмов решения задачи.

# %% [markdown]
# ## Постановка задачи

# %% [markdown]
# Аналитически решить задачу о раскрасках; графически отобразить решения задачи с использованием системы компьютерной алгебры SageMath. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Порядок выполнения работы

# %% [markdown]
# 1. Аналитически решить задачу о раскрасках для заданного варианта. Все умозаключения в ходе решения обосновать и содержательно проинтерпретировать.
#
# 2. Реализовать средствами SageMath функцию, отображающую графически раскраску по заданному номеру. Продемонстрировать работу функции на нескольких примерах. Сделать выводы.
#
# 3. Дополнительное необязательное задание: для заданного варианта решить задачу в общем виде.

# %% [markdown]
# ## Основные теоретические положения

# %% [markdown]
# #### Определение 1

# %% [markdown]
# Пусть $G$ - группа, $e$ - нейтральный элемент группы $G$, $X$ - множество. $G$ действует на $X$, если задана операция $G x X -> G$.
# Тогда $\forall x \in X$, $\forall g,h \in G$:
# 1) $ex=x$
#
# 2) $g(hx)=(gh)x$

# %% [markdown]
# #### Определение 2

# %% [markdown]
# Орбитой $x \in  X $ под действием группы $G$ называется множество $Gx = \{gx | g \in G\}$. Количество элементов в данной орбите называется длиной орбиты.

# %% [markdown]
# #### Определение 3

# %% [markdown]
# Орбитой  x∈X  под действием группы  G  называется множество  Gx={gx|g∈G} . Количество элементов в данной орбите называется длиной орбиты.

# %% [markdown]
# #### Определение 4

# %% [markdown]
# Неподвижными точками элемента $g \in G$ называют те $x \in  X$ для которых выполнено : $gx = x$.
#
# Обозначение множества неподвижных точек элемента $g$: $ X^g$

# %% [markdown]
# #### Определение 5

# %% [markdown]
# Пусть $I$ - произвольное множество, а $C$ - множество цветов. Раскраской множества $I$ называется функция из $I$ в $C$. $C^{I}$ - множество всех раскрасок.

# %% [markdown]
# #### Определение 6

# %% [markdown]
# Пусть $G$ группа, действующая на множестве $I$. Тогда $gf(i) = f(g^{-1}i)$ задает действие $G$ на $C^{I}$, где $g \in G$, $i \in I$, $f \in C^{I}$.

# %% [markdown]
# #### Лемма Бёрнсайда

# %% [markdown]
# Количество орбит действия группы $G$ на множество $X$ вычисляется по формуле: $N= \frac{1}{_{\#G}} \cdot \sum_{g \in G}\# X^g $

# %% [markdown]
# #### Теорема

# %% [markdown]
# Для элемента $g \in G$ и функции $f \in C^{I}$ следующие условия эквивалентны:
#
# 1)$gf = f$
#
# 2)$f(i) = f(g^{n}i)$, $\forall i \in I $ и $n \in \mathbb{Z}$
#
# 3)Если $i,j \in I$ лежат в одном цикле в циклической записи перестановки $\varphi(g)$, то $f(i) = f(j)$ (в терминологии задачи о бусах, это означает, что все места из одного цикла покрашены в одинаковый цвет)

# %% [markdown]
# #### Определение 7

# %% [markdown]
# Количество раскрасок из $C^I$, которые сохраняют элемент $g \in G$ равно $|C|^{c(\alpha(g))}$, где $c(\alpha)$ - количество независимых циклов в перестановке $\alpha$.

# %% [markdown]
# ## Задание

# %% [markdown]
# Сколькими способами можно составить бусы из 74 бусинок 6 различных цветов (с точностью до поворотов и осевых симметрий)?

# %% [markdown]
# ## Выполнение работы

# %% [markdown]
# ### Аналитическое решение задачи с соответствующими комментариями

# %% [markdown]
# Под различными бусами подразумеваются те, которые нельзя совместить друг с другом с помощью поворотов и осевой симметрии.
#
# Пусть нам дано множество цветов $\{a,b,c,d,e,f\}$ и множество бусинок {$x_1$,$x_2$,...,$x_{34}$} $\forall i\  x_i \in \{a,b,c,d,e,f\}$. Всего количество бус $6^{74}$. Существует всего $6^{74}$ таких раскрасок, но не все из них соответствуют различным бусам.
#
# На множестве $X$ всех раскрасок действует группа поворотов и осевых симметрий. Операцией в этой группе является композиция. Операция является ассоциативной, нейтральный элемент - тождественное отображение, обратным к осевой симметрии является она сама, обратным к повроту - поворот в обратную сторону. Обозначим группу буквой $G$.
#
# Задано отображение из $G$ в симметрическую группу $S_{74}$. Пусть $\tau$ - поворот, переводящий каждое место в следующее, а $\sigma$ - осевая симметрия
#
# Выпишем некоторые перестановки (в циклической форме) из $S_{74}$, в которые переходят элементы группы $G$:

# %% [markdown]
# $e =  \begin{pmatrix}
#   1, 2, 3, ..., 74\\
#   1, 2, 3, ..., 74
#  \end{pmatrix} = (1)(2)(3)...(74)$
#
# $\tau = \begin{pmatrix}
#   1, 2,3, ..., 73, 74\\
#   2, 3, 4, ..., 74, 1
#  \end{pmatrix} = (1,2,3,...,74)$
#
#
# $\tau^2 = \begin{pmatrix}
#   1, 2,3, ..., 73, 74\\
#   3, 4, 5, ..., 1, 2
#  \end{pmatrix} = (1,3,...,73)(2,4,...,74)$
#
#
# $\sigma = \begin{pmatrix}
#   1, 2,3, ..., 73, 74\\
#   74, 73, ..., 2, 1
#  \end{pmatrix} = (1,74)(2,73)(3,32)...(37,38)$

# %% [markdown]
# Перестановка $\tau$ является циклом длины 74, исходя из Леммы 2 можно посчитать количество циклов в перестановке $\tau^i\ \forall i$. Число 74 раскладывается на простые множители как 74 = 2*37. Каждая перестановка $\tau^i$ является произведением d независимых циклов, где d:= НОД(74,i).

# %% [markdown]
# $\forall i\$ не кратных 2 или 37: d = 1
#
# $\forall i\$ кратных 2 но не кратных 37: d = 2
#
# $\forall i\$ кратных 37 но не кратных 2: d = 37

# %% [markdown]
# $\#X^e = 6^{74}$
#
# $\# X^{\tau^k} = 6$ , $\forall k \in \{1,...,73\}$ : $k \% 2 \neq 0\, \ k \% 37 \neq 0$ (36 значений)
#
# $\# X^{\tau^u} = 6^2$, $\forall u \in \{1...,73\}$ :  $k \% 2 = 0\,$ (36 значений)
#
# $\# X^{\tau^z} = 6^{37}$, z = 37 (1 значение)
#
#
# $|X^{\sigma \tau^{r}}|$ = $6^{37}$ где r - чётный, r = {1 , ... , 73}, (36 четных)
#
# $|X^{\sigma \tau^{u}}|$ = $6^{38}$ где u - нечётный, u = {1 , ... , 3=73}, (37 нечетных)
#
# $\# G = 148$

# %% [markdown]
# Согласно лемме Бернсайда количество различных бус равно: $\frac{1}{148}(6^{74} + 36\cdot 6 + 36 \cdot 6^2 + 6^{37} + 36 \cdot 6^{37} + 37 \cdot 6^{38})$

# %% [markdown]
# ### Реализация функции отображения раскраски

# %%
import random

def Tau(beads):
    return [beads[-1]] + beads[:-1]

def Sigma(beads):
    return beads[::-1]

def print_coloring(beads):
    color = {1 : 'red', 2 : 'green', 3 : 'blue', 4 : 'yellow', 5 : 'pink', 6: 'indigo'}
    G = graphs.CycleGraph(74)
    recolor = {'red' : [], 'green' : [], 'blue' : [], 'yellow' : [], 'pink' : [], 'indigo' : []}
    G.relabel({i:beads[i][0] for i in range(0,74)})
    for item in beads:
        recolor[color[item[1]]].append(item[0])
    plt = G.graphplot(vertex_colors=recolor)
    plt.show(figsize=[7,7])

beads = [[j, random.randint(1,6)] for j in range(1, 75)]

# %% [markdown]
# #### Изначальные бусы

# %%
print_coloring(beads)
# Out:
# Graphics object consisting of 149 graphics primitives

# %% [markdown]
# #### Двойной поворот

# %%
rotate = Tau(Tau(beads))
print_coloring(rotate)
# Out:
# Graphics object consisting of 149 graphics primitives

# %% [markdown]
# #### Симметричное отображение

# %%
sym = Sigma(beads)
print_coloring(sym)
# Out:
# Graphics object consisting of 149 graphics primitives

# %% [markdown]
# #### Один поворот и симметричное отображение

# %%
rotate_sym = Sigma(Tau(beads))
print_coloring(rotate_sym)
# Out:
# Graphics object consisting of 149 graphics primitives

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Получена практика решения задач о раскрасках, пользуясь леммами Бёрнсайда. Была аналитически решена задача о раскрасках. Реализованы процедуры перестановок, процедуры, отображающие графически раскраску. Получены навыки решения задач с перестановками.
