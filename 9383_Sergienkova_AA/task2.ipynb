# %% [markdown]
# # Практическая работа №2: Исследование задач о раскрасках

# %% [markdown]
# Выполнила студентка гр. 9383 Сергиенкова Анастасия, вариант 107.

# %% [markdown]
# ## Цель работы:
#
# Формирование представления о задачах о раскрасках, выработать умение использование леммы Бёрнсайда для решения задачи о раскрасках, привить навык использования систем компьютерной алгебры для реализации алгоритмов решения задачи.

# %% [markdown]
# ## Основные теоретические положения.

# %% [markdown]
# ### Определение действия группы на множество.
#
# Пусть $G$ - некая группа с нейтральным элементом $e$, а $X$ - какое-то множество. $G$ действует на $X$, если задана операция $G \times X \to X$, которая обладает для $\forall x \in X$ и $\forall g,h \in G$ следующими свойствами:
#
# 1) $ex = x$
#
# 2) $g(hx) = (gh)x$
#
# где $gx$ - это образ пары $(g,x)$.

# %% [markdown]
# ### Определение орбиты.
#
# Орбитой элемента $x \in X$ под действием $G$ называется множество $Gx = \{gx | g \in G\}$. Количество точек в данной орбите называется длиной орбиты. Любые две орбиты либо не пересекаются, либо совпадают. Таким образом, множество $X$ разбивается в дизъюнктивное объединение орбит.

# %% [markdown]
# ### Определение неподвижных точек.
#
# Неподвижными точками элемента $g \in G$ называются такие $x \in X$, для которых $gx = x$. Множество неподвижных точек элемента $g$ обозначается через $X^{g}$.

# %% [markdown]
# ### Лемма Бёрнсайда.
#
# Количество орбит действия группы $G$ на множестве $X$ равно: $\frac{1}{|G|}\sum\limits_{g\in G}|X^{g}|$

# %% [markdown]
# ### Определение множества раскрасок.
#
# Пусть $I$ - произвольное множество, а $C$ - множество цветов.Расскраской множества $I$ называется функция из $I$ в $C$. Множество всех раскрасок обозначается через $C^I$. $|C^I| = |C|^{|I|}$
#
# #### Oпределение 1
# Пусть $G$ группа, действующая на множестве $I$. Тогда формула $gf(i) = f(g^{-1}i)$, где $g \in G$, $i \in I$, а $f \in C^{I}$ задает действие $G$ на $C^{I}$.
#
# #### Oпределение 2
# Для элемента $g \in G$ и функции $f \in C^{I}$ следующие условия эквивалентны:
#
# 1. $gf = f$
#
# 2. $f(i) = f(g^{n}i)$, $\forall i \in I $ и $n \in \mathbb{Z}$
#
# 3. Если $i,j \in I$ лежат в одном цикле в циклической записи перестановки $\varphi(g)$, то $f(i) = f(j)$

# %% [markdown]
# ### Количество раскрасок.
#
# Количество раскрасок из $C^{I}$, которые сохраняет данный элемент $g \in G$ равно $|C|^{c(\varphi(g))}$, где $c(\varphi(g))$ - количество независимых циклов перестановки $\varphi(g)$ (считая циклы длины 1).

# %% [markdown]
# ### Лемма 2
#
# Предположим, что $\tau$ является циклом длины $k$, а $\gcd(k \, n$) $= d$. Тогда перестановка $\tau^n $ является произведением $d$ циклов длины $\frac{k}{d}$.

# %% [markdown]
# ## Постановка задачи.
#
# Аналитически решить задачу о раскрасках; графически отобразить решения задачи с использованием системы компьютерной алгебры SageMath. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# #### Вариант 107
#
# Круг разбит на 30 секторов, каждый из которых покрашен в один из 5 цветов. Сколькими способами можно составить такую мозайку (с точностью до поворота круга)?

# %% [markdown]
# ## Порядок выполнения работы:
#
# 1. Аналитически решить задачу о раскрасках для заданного варианта. Все умозаключения в ходе решения обосновать и содержательно проинтерпретировать.
#
# 2. Реализовать средствами SageMath функцию, отображающую графически раскраску по заданному номеру. Продемонстрировать работу функции на нескольких примерах. Сделать выводы.
#
# 3. Дополнительное необязательное задание: для заданного варианта решить задачу в общем виде.

# %% [markdown]
# ## Выполнение работы.

# %% [markdown]
# ### Аналитическое решение задачи о раскрасках

# %% [markdown]
# Дано множество из 5 цветов $\mathbb{C}$ и множество секторов круга $I = \{x_1, x_2, \ldots, x_{30}\}$, $x_i \in \mathbb{C}$. Необходимо найти количество различных способов раскрасить сектора круга с точностью до поворота круга.
#
# Всего вариантов раскраски секторов круга: $5^{30}$.
#
# На множество $\mathbb{C}^I$ всех раскрасок действует группа поворотов $\mathbb{G}$ с операцией композиции. Для решения задачи нужно найти количество орбит действия группы $\mathbb{G}$ на множество $\mathbb{C}^I$.
#
# Пусть $\tau$ - поворот (поворот на $\frac{36}{3}$ градусов).
#
# Тогда $\mathbb{S}_I = \{e=\tau^{0}, \tau^{1}, \tau^{2}, \ldots, \tau^{28}, \tau^{29}\}.$

# %% [markdown]
# Выпишем все возможные элементы симметрической группы $\mathbb{S}_I$:
#
# $e =\begin{pmatrix} 1&2&3&\ldots&30 \\ 1&2&3&\ldots&30 \end{pmatrix} = (1)(2)(3)\ldots(29)(30)$
#
# $\tau = \begin{pmatrix} 1&2&3&\ldots&29&30 \\ 2&3&4&\ldots&30&1 \end{pmatrix} = (1, 2, 3, \ldots, 29, 30)$
#
# $\tau^2 = \tau(\tau) = \begin{pmatrix} 1&2 &3 &\ldots&29 &30 \\ 3 &4 &5 &\ldots &1 &2 \end{pmatrix} = (1, 3, 5, \ldots, 27, 29)(2, 4, 6, \ldots, 28, 30)$
#
# $\ldots$
#
#
# $\tau^{5} = \begin{pmatrix} 1 &2 &3 &\ldots &28 &29 &30 \\6 &7&8&\ldots&3&4&5 \end{pmatrix} = (1, 6, \ldots, 26)(2, 7, \ldots, 27)(3, 8, \ldots, 28)(4, 9, \ldots, 29)(5, 10, \ldots, 30)$
#
# $\ldots$
#
# $\tau^{30} = \begin{pmatrix} 1 &2 &3 &\ldots &29 &30 \\ 30 &1 &2 &\ldots &28 &29 \end{pmatrix} = (30, 29, 28, \ldots, 2, 1)$
#
# $\tau^{30} = e$

# %% [markdown]
# Воспользуемся леммой Бёрнсайда для нахождения количества раскрасок. Для этого мы сначала находим количество независимых циклов во всех перестановках, полученных после применения $ \tau^ n $. Для этого воспользуемся леммой 2. Число 30 делится на 1, 2, 3, 5, 6, 10 и 15.

# %% [markdown]
# | НОД(70, k) | X | n |
# | :-: | :-: | :-: |
# | 1 | {1, 7, 11, 13, 17, 19, 23, 29} | 8 |
# | 2 | {2, 4, 8, 14, 16, 22, 26, 28} | 8 |
# | 3 | {3, 9, 21, 27} | 4 |
# | 5 | {5, 25} | 2 |
# | 6 | {6, 12, 18, 24} | 4 |
# | 10 | {10, 20} | 2 |
# | 15 | {15} | 1 |

# %% [markdown]
# Количество независимых циклов: 1
#
# Теперь воспользуемся леммой Бёрнсайда:
#
# Количество различных способов раскрасить сектора круга с точностью до поворота круга равно: $N = \frac{1}{|\mathbb{G}|} \sum_{g \in \mathbb{G}}{|\mathbb{X}^g|} = \frac{1}{30}(5^{30} + 8 \cdot 5^{1} + 8 \cdot 5^{2} + 4 \cdot 5^{3} + 2 \cdot 5^{5} + 4 \cdot 5^{6} + 2 \cdot 5^{10} +1 \cdot 5^{15} + 1\cdot 5)$

# %%
import matplotlib.pyplot as plt
from random import randint 

def Circle(colors, x = 0):
    x = x % 30
    sizes = [360/30 for _ in range(30)]
    labels = [str(i+1) for i in range(30)]
    plt.figure(figsize = (18,18))
    plt.pie(sizes,
            labels = labels, 
            colors = colors, 
            labeldistance = 1.02, 
            startangle = 360/30*n+90,
            wedgeprops = {"linewidth": 1, 'width':1, "edgecolor":"black"}
            ) 
c =['purple', 'lavender', 'indigo', 'teal', 'salmon']
colors = [c[randint(0, 4)] for i in range(30)]

draw(colors)
plt.show()

# %%
x = 20
print(f"Поворот на {x} секторов")
draw(colors, x)
# Out:
# Поворот на 20 секторов

# %%
x = 10
print(f"Поворот на {x} секторов")
draw(colors, x)
# Out:
# Поворот на 10 секторов

# %% [markdown]
# ## Вывод
#
# В ходе выполнения практической работы были сформированы представления о задачах о раскрасках, выработано умение использования леммы Бёрнсайда для решения задачи о раскрасках. Была написана программа, отображающая графическое изображение раскраски.
