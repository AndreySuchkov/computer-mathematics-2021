# %% [markdown]
# # Практическая работа №1: Исследование алгоритмов формирования аддитивных цепочек
#
# Выполнил студент гр. 9303 Емельянов Семён, вариант 5.

# %% [markdown]
# ## Цель работы
# Формирование представления о аддитивных цепочках, выработать умение составлять и применять алгоритмы для нахождения минимальных аддитивных цепочек для заданного числа, привить навык использования систем компьютерной алгебры для реализации алгоритмов.

# %% [markdown]
# ## Основные теоретические положения
#
# ### Бинарный метод
#
#  Бинарный метод - это один из алгоритмов быстрого возведения числа ${x}$ в некоторую степень ${n\in \mathbb{N}}$.
#
#  Основной идеей данного метода является разбиение искомого числа ${x^n}$ на произведение ${x}$ в некоторых степенях. Результат считается по следующим правилам:
#
#  Пусть текущий результат изначально равен ${x}$. Слева направо просматривается бинарная запись числа ${n}$ без первого бита. Если текущий бит записи равен 1 - текущий результат возводится в квадрат и затем умножается на число ${x}$. Если текущий бит записи равен 0 - текущий результат возводится в квадрат.
#
#
# ### Метод множителей
#
#  Метод множителей базируется на бинарном методе. Пусть дано исходное число ${x}$, которое нужно возвести в степень ${n}$. Число n раскладывается на произведение двух множителей, например: ${n = i*j}$, причем ${i}$ - наименьший простой множитель и ${x^n = (x^i)^j}$. Далее сначала считаем ${x^i}$ при помощи бинарного метода, затем получившийся результат возводим в степень ${j}$. Если ${n}$ - простое число, то на множители раскладывается число ${n - 1}$ и после получения значения $x^{n - 1}$ домножаем его на ${x}$.
#
#
# ### Аддитивная цепочка
#
#  Аддитивная цепочка — это последовательность натуральных чисел $\{a_i\}_{i=0}^m$, где ${a_0 = 1}$, ${a_m = n}$, а каждый из остальных элементов является суммой двух элементов, предшествующих ему. Эти два элемента могут быть равны. Например:
#
#  ${a_0 = 1}$
#
#  ${\forall i > 0, a_i = a_j + a_k , j,k < i}$
#
#  В аддитивной цепочке встречаются три типа шагов. ${i}$-шаг является:
#
# - удвоением, если ${j = k = i - 1}$
#
# - звездным шагом, если ${j = i - 1}$, ${k = \overline{0 .. (i-1)}}$
#
# - малым шагом, если ${\lambda(a_i) = \lambda(a_{i-1})}$
#
# ### Звездная цепочка
#
#  Звездной цепочкой называют аддитивную цепочку, состоящую только из звездных шагов.
#
#
# ### Теорема Брауэра
#
#  При нектором $k < lb(lbn)$ справедливо: $l(n) < (1+k^{-1})\cdot\lceil lbn\rceil+2^{k-1}-k+2$.
#
# #### Следствие 1.
#  Пусть $k = \lambda(\lambda(n))-2\lambda(\lambda(\lambda(n)))$, тогда $\lim\limits_{x\to\infty} \cfrac{l(n)}{\lambda(n)} = 1$.
#
# #### Следствие 2.
#  Наилучшая верхняя оценка для l(n) имеет вид: $\lambda(n)\bigg(1+\cfrac{1}{\lambda(\lambda(n))}+\cfrac{o(\lambda(\lambda(\lambda(n))))}{(\lambda(\lambda(n)))^2}\bigg)$
#
# ### Алгоритм Брауэра
#
#  Данный алгоритм является алгоритмом вычисления приближённых аддитивных цепочек для различных чисел при варьировании параметра $k \geq 2$. Цепочки, вычисленные алгоритмом Брауэра, называются Брауэрскими и задаются рекурентной формулой:
# $$
# B_k(n) =\begin{cases}1, 2, 3, ..., 2^k-1\text{, } n<2^k \\ B_k(q), 2q, 4q, 8q, ..., 2^kq, n,\text{ } n \geqslant 2^k\ \text{и } q = \lfloor\frac{n}{2^k}\rfloor \end{cases}
# $$
#
# *Звёздная цепочка* $-$ это цепочка, которая содержит в себе только звёздные шаги. $a_i = a_{i-1} + a_k\text{, где } 0\leqslant k\leqslant i-1 $. $l^*(n)$ - длина звёздной цепочки. $l^*(n)\geqslant l(n)$
#
#
# ### Алгоритм дробления вектора индексов
#
#  Пусть имеется число ${n\in \mathbb{N}}$. Задачей алгоритма является нахождения минимальной звёздной(линейной) цепочки такой, что ${a_m = 0}$.
#
#  Описание алгоритма:
#
# 1. Запускаем внешний цикл по длинам цепочек ${\underline{l}(n)\leq m\leq \overline{l}(n)}$. Где ${\underline{l}(n) =\lambda (n)}$, а ${\overline{l}(n) =\lambda(n) +\nu(n) - 1}$. Пусть  ${q = m//2 - 1}$.
#
# 2. Запускаем внутрненний цикл перебора всех ${\{r_i\}_{i=1}^{q}}$.
#
#  На каждом шаге вычисляем ${a_{min} = a_{q+1} + m - q}$ и ${a_{max} = a_{q+1}2^{m-q}}$
#
# 1. Если последний элемент в цепочки равен числу ${n}$, заканчиваем алгоритм.
#
# 2. Если ${n\in [a_{min}, a_{max}] $ , то тогда перебираем часть вектора индексов ${\{r_j\}_{j=q+1}^m}$
#
# 3. Если ${n\notin [a_{min}, a_{max}]}$ , то тогда перебираем часть вектора индексов ${\{r_i\}_{i=1}^q}$
#
#
# ### Гипотеза Шольца-Брауэра:
#
#  Гипотеза Шольца-Брауэра заключается в следующем: ${l^*(2^n-1) \leq l^*(n)+n-1}$

# %% [markdown]
# ## Постановка задачи
# Реализовать точные и приближённые алгоритмы нахождения минимальных аддитивных цепочек с использованием систем компьютерной алгебры SageMath, провести анализ алгоритмнов. Полученные результаты содержательно проинтерпретировать.
#
# ## Порядок выполнения работы
#
# 1. Применить бинарный метод и метод множителей для $x^n$, где $n\geq 30$, для 2-3 значений $n$ (значения $n$ выбирается студентом самостоятельно). Сравнить количество операций для каждого метода, сделать выводы.
# 2. Реализовать алгоритм Брауэра для вычисления приближённых аддитивных цепочек для различных чисел при варьировании параметра $k$, сопоставить длины полученных аддитивных цепочек с минимальной аддитивной цепочкой для заданного числа. Сделать выводы.
# 3. Реализовать алгоритм дробления вектора индексов для нахождения минимальной звёздной цепочки для заданного числа. Протестировать алгоритм при $n \geq 500$. Указать, сколько времени потребовалось на поиск цепочки и какая цепочка получилась. Сравнить с предыдущими методами, сделать выводы.
# 4. Проверить следствие 1 теоремы Брауэра для $n=1..200$ путём построения функции $l(n)$ и аппроксимирующей кривой, полученной с помощью метода наименьших квадратов. Сопоставить функции на одном графике, сделать выводы.
# 5. Проверить гипотезу Шольца–Брауэра для $1<n \leq 10$ на алгоритме дробления вектора индексов. Сделать выводы.
# 6. *Дополнительное необязательное задание: найти и/или предложить модификации алгоритмов и привести описание модификаций. Реализовать модифицированные алгоритмы и сравнить их мощность*.

# %% [markdown]
# ## Выполнение работы
#
# ### 1. Решение задач вычисления степеней бинарным методом и методом множителей.
#
#  **Применим бинарный метод для** $x^{48}$, $x^{33}$, $x^{127}$**:**
#
#  *Для $x^{48}$:* Представим показатель степени в двоичном виде: $48_{10}$ = $110000_2$. Отбрасываем первый бит, получаем $10000_2$. Далее заменяем 0 в записи числа на умножение текущего числа на самого себя, заменяем 1 на умножение текущего числа на себя и умножение его на исходное - $x$.
#
# $$ x*x = x^{2} $$
# $$ x^{2}*x = x^{3} $$
# $$ x^{3}*x^{3} = x^{6} $$
# $$ x^{6}*x^{6} = x^{12} $$
# $$ x^{12}*x^{12} = x^{24} $$
# $$ x^{24}*x^{18} = x^{24} $$
#
#  Количество операций - 6.
#
#  *Для $x^{33}$:* Представим показатель степени в двоичном виде: $33_{10}$ = $100001_2$. Отбрасываем первый бит, получаем $00001_2$.
#
# $$ x*x = x^{2} $$
# $$ x^{2}*x^{2} = x^{4} $$
# $$ x^{4}*x^{4} = x^{8} $$
# $$ x^{8}*x^{8} = x^{16} $$
# $$ x^{16}*x^{16} = x^{32} $$
# $$ x^{32}*x = x^{33} $$
#
#  Количество операций - 6.
#
#  *Для $x^{127}$:* Представим показатель степени в двоичном виде: $127_{10}$ = $1111111_2$. Отбрасываем первый бит, получаем $111111_2$.
#
# $$ x*x = x^{2} $$
# $$ x^{2}*x = x^{3} $$
# $$ x^{3}*x^{3} = x^{6} $$
# $$ x^{6}*x = x^{7} $$
# $$ x^{7}*x^{7} = x^{14} $$
# $$ x^{14}*x = x^{15} $$
# $$ x^{15}*x^{15} = x^{30} $$
# $$ x^{30}*x = x^{31} $$
# $$ x^{31}*x^{31} = x^{62} $$
# $$ x^{62}*x = x^{63} $$
# $$ x^{63}*x^{63} = x^{126} $$
# $$ x^{126}*x = x^{127} $$
#
#  Количество операций - 12.
#
#
#  **Для этих же степеней -** $x^{48}$, $x^{33}$, $x^{127}$ **- применим метод множителей:**
#
#  *Для $x^{48}$:* Разбиваем показатель степени на простые множители: $x^{48} = (x^2)^{24} = ((x^2)^2)^{12} = (((x^2)^2)^2)^{6} = ((((x^2)^2)^2)^2)^3$. Представим $(((x^2)^2)^2)^2$ как $x^16$. Для $16_{10}$ = $10000_2$. Отбрасываем первый бит, получаем $0000_2$. Для $3_{10}$ = $11_2$. Отбрасываем первый бит, получаем $1_2$
#
# $$ x*x = x^{2} $$
# $$ x^{2}*x^{2} = x^{4} $$
# $$ x^{4}*x^{4} = x^{8} $$
# $$ x^{8}*x^{8} = x^{16} = y $$
# $$ y*y = y^{2} $$
# $$ y^{2}*y = y^{3} $$
#  Имеем $y^{3} = (x^{16})^{3} = x^{48}$.
#
#  Количество операций - 6.
#
#  *Для $x^{33}$:* Разбиваем показатель степени на простые множители: $x^{33} = (x^3)^11$.
#
# $$ x*x = x^{2} $$
# $$ x^{2}*x = x^{3} = y $$
# $$ y*y = y^{2} $$
# $$ y^{2}*y^{2} = y^{4} $$
# $$ y^{2}*y = y^{5} $$
# $$ y^{5}*y^{5} = y^{10} $$
# $$ y^{10}*y = y^{11} $$
#  Имеем $y^{11} = (x^{3})^{11} = x^{33}$.
#
#  Количество операций - 7.
#
#  *Для $x^{127}$:* Представим $x^{127}$ как $x*x^{126}$ Разбиваем показатель степени на простые множители: $x^{126} = (x^2)^{63} = ((x^2)^3)^{21} = (((x^2)^3)^3)^{7}$.
#
# $$ x*x = x^{2} = y $$
# $$ y*y = y^{2} $$
# $$ y^{2}*y = y^{3} = z $$
# $$ z*z = z^{2} $$
# $$ z^{2}*z = z^{3} = t $$
# $$ t*t = t^{2} $$
# $$ t^{2}*t = t^{3} $$
# $$ t^{3}*t^{3} = t^{6} $$
# $$ t^{6}*t = t^{7} $$
# $$ x*(t^{7}) = x*((((x^{2})^{3})^{3})^{7}) = x*x^{126} = x^{127} $$
#
#  Количество операций - 10.
#
#
#  **Результаты возведения в степень:**
#
# |Степень|Число операций БМ|Число операций ММ|
# |:-----:|:---------------:|:---------------:|
# |48     |6                |6                |
# |55     |6                |7                |
# |127    |12               |10               |
#
#  **Вывод:**
#
#  *При степенях $n = 2^k-1, k \in N$ метод множителей оказывается эффеткивнее бинарного метода. При степенях $n = 2^k+1, k = 5,6,...$ бинарный метод оказывается эффективнее. В остальных случаях оба метода выполняются за одно и то же число операций или метод множителей выполняется быстрее, но не значительно.*

# %% [markdown]
# ### Реализация алгоритма Брауэра.
#
#  Данный алгоритм позволяет вычислять приближённые аддитивные цепочеки для различных чисел при варьировании параметра k. Ниже представлена реализация алгоритма Брауэра.

# %%
def BrowerAlgorithm(n, k, Bn):
    list_of_mods = []
    power = 2 ** k
    check = n
    while check >= power:
        list_of_mods.append(check % power)
        check //= power

    list_of_mods.append(check)
    list_of_mods.reverse()
    current_power = 0
    x = 1
    Bn.append(x)
    while (x != list_of_mods[current_power]):
        x += 1
        Bn.append(x)

    while (x != n):
        pow2 = 0
        while (pow2 != k):
            pow2 += 1
            x *= 2
            Bn.append(x)
        current_power += 1
        x += list_of_mods[current_power]
        Bn.append(x)
    return Bn



if __name__ == "__main__":
    print("Метод Брауэра")
    N = int(input("Введите N: "))
    K = int(input("Введите K: "))
    Bn = BrowerAlgorithm(N, K, [])
    print(Bn)
    print("Длина аддитивной цепочки: ", len(Bn))
# Out:
# Метод Брауэра
# Введите N: 1666
# Введите K: 4
# [1, 2, 3, 4, 5, 6, 12, 24, 48, 96, 104, 208, 416, 832, 1664, 1666]
# Длина аддитивной цепочки:  16

# %% [markdown]
#  **Для сравнения результатов алгоритма Брауэра и минимальных аддитивных цепочек были взяты следующие числа: 48, 33, 127, 555, 1024.**
#
#  *Результаты алгоритма Брауэра для $n = 48$ при $k\in\{2, 3, 4\}$:*
#
# |k    |Длина|Цепочка                         |
# |:---:|:---:|:------------------------------:|
# |2    |9    |1, 2, 3, 6, 12, 12, 24, 48, 48  |
# |3    |10   |1, 2, 3, 4, 5, 6, 12, 24, 48, 48|
# |4    |8    |1, 2, 3, 6, 12, 24, 48, 48      |
#
#  *Минимальная аддитивная цепочка для $n = 48$ (длины 8): \[1, 2, 3, 6, 12, 24, 48, 48\].*
#
#  *Результаты алгоритма Брауэра для $n = 33$ при $k\in\{2, 3, 4\}$:*
#
# |k    |Длина|Цепочка                  |
# |:---:|:---:|:-----------------------:|
# |2    |8    |1, 2, 4, 8, 8, 16, 32, 33|
# |3    |8    |1, 2, 3, 4, 8, 16, 32, 33|
# |4    |7    |1, 2, 4, 8, 16, 32, 33   |
#
#  *Минимальная аддитивная цепочка для $n = 33$ (длины 7): \[1, 2, 4, 8, 16, 32, 33\].*
#
#  *Результаты алгоритма Брауэра для $n = 127$ при $k\in\{2, 3, 4\}$:*
#
# |k    |Длина|Цепочка                                  |
# |:---:|:---:|:---------------------------------------:|
# |2    |10   |1, 2, 4, 7, 14, 28, 31, 62, 124, 127     |
# |3    |9    |1, 2, 4, 8, 15, 30, 60, 120, 127         |
# |4    |12   |1, 2, 3, 4, 5, 6, 7, 14, 28, 56, 112, 127|
#
#  *Минимальная аддитивная цепочка для $n = 127$ (длины 9): \[1, 2, 4, 8, 15, 30, 60, 120, 127\].*
#
#  *Результаты алгоритма Брауэра для $n = 555$ при $k\in\{2, 3, 4\}$:*
#
# |k    |Длина|Цепочка                                               |
# |:---:|:---:|:----------------------------------------------------:|
# |2    |14   |1, 2, 4, 8, 8, 16, 32, 34, 68, 136, 138, 276, 552, 555|
# |3    |13   |1, 2, 4, 8, 8, 16, 32, 64, 69, 138, 276, 552, 555     |
# |4    |12   |1, 2, 4, 8, 16, 32, 34, 68, 136, 272, 544, 555        |
#
#  *Минимальная аддитивная цепочка для $n = 555$ (длины 12): \[1, 2, 4, 8, 16, 32, 34, 68, 136, 272, 544, 555\].*
#
#  *Результаты алгоритма Брауэра для $n = 1024$ при $k\in\{2, 3, 4\}$:*
#
# |k    |Длина|Цепочка                                                          |
# |:---:|:---:|:---------------------------------------------------------------:|
# |2    |16   |1, 2, 4, 4, 8, 16, 16, 32, 64, 64, 128, 256, 256, 512, 1024, 1024|
# |3    |14   |1, 2, 4, 8, 16, 16, 32, 64, 128, 128, 256, 512, 1024, 1024       |
# |4    |14   |1, 2, 3, 4, 8, 16, 32, 64, 64, 128, 256, 512, 1024, 1024         |
#
#  *Минимальная аддитивная цепочка для $n = 1024$ (длины 14): \[1, 2, 3, 4, 8, 16, 32, 64, 64, 128, 256, 512, 1024, 1024\].*
#
#  **Вывод:**
#
#  *На основе представленных выше результатов можно сделать вывод, что при увеличении $k$ в алгоритме Брауэра длина аддитивной цепочки увеличивается, следовательно увеличивается и расхождение с минимальной длиной аддитивной цепочки.*

# %% [markdown]
# ### Реализация алгоритма дробления вектора индексов для нахождения минимальной звёздной цепочки для заданного числа.
#
# Данный алгоритм является точным алгоритмом и находит минимальную звёздную цепочку для числа $n$. Ниже представлена реализация алгоритма дробления вектора индексов.

# %%
def splitting(n):
    for m in range(int(n).bit_length(), int(n).bit_length()+bin(int(n)).count('1')):
        vector = [i for i in range(1, m)]
        q = m // 2 - 1

        while True:
            chain = [1]
            for i in vector:
                chain.append(chain[-1] + chain[i-1]) 
            if chain[m-1] == n: 
                return chain

            if n < (chain[q]+m-q) or chain[q]*2**(m-q) < n:
                for i in range(0, q, -1):        
                    if vector[i-1] > 1:
                        vector[i-1] -= 1
                        break
                    else: 
                        vector[i-1] = i
                if sum(vector[:q]) == abs(q):
                    break 
            
            else:
                for i in range(m-1, q, -1):        
                    if vector[i-1] > 1:
                        vector[i-1] -= 1
                        break
                    else: 
                        vector[i-1] = i
                if sum(vector[q:]) == abs(m-q-1):
                    break  
                        
    return chain


if __name__ == "__main__":
    print("Алгоритм дробления вектора индексов")
    N = int(input("Введите N: "))
    V = splitting(N)
    print(V)
    print("Длина звёздной цепочки: ", len(V))
# Out:
# Алгоритм дробления вектора индексов
# Введите N: 777
# [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 768, 776, 777]
# Длина звёздной цепочки:  13

# %% [markdown]
#  *Результаты работы алгоритма дробления ветктора индексов для $n = 555, 1025, 1666$:*
#
# |n    |Длина цепочки|Цепочка                                                      |Время поиска, c|
# |:---:|:-----------:|:-----------------------------------------------------------:|:-------------:|
# |555  |13           |1, 2, 4, 8, 16, 32, 64, 72, 136, 137, 209, 418, 555          |9.45           |
# |1025 |12           |1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 1025            |1.99           |
# |1666 |14           |1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 1536, 1664, 1666|53.03          |
#
#  *Сравнение длин цепочек, полученных различными методами и алгоритмами:*
#
# |n    |Бинарный метод|Метод множителей|Алгоритм Брауэра|Алгоритм дробления вектора индексов|
# |:---:|:------------:|:--------------:|:--------------:|:---------------------------------:|
# |555  |14            |13              |12              |13                                 |
# |1025 |12            |14              |14              |12                                 |
# |1666 |14            |15              |15              |14                                 |
#
#
#  **Вывод:**
#
#  *На основе первой таблицы можно сделать вывод, что алгоритм дробления вектора индексов даёт аддитивную цепочку минимальной длины, но при этом вычисления занимают много времени. При сравнении длин цепочек можно сделать вывод, что из предыдущих алгоритмов ближе к точному результату бинарный метод.*

# %% [markdown]
# ### Проверка следствия теоремы Брауэра.

# %%
import pylab
from math import e, log

def print_graph(n, f):
    
    x, y, count, lnx, lnxq, power = [],[],[],[],[],[]
    
    for i in range(1, n):
        x.append(i)
        count.append(len(f(i)))
        lnx.append(log(i, e))
        lnxq.append(log(i, e)**2)
        power.append(count[i-1] * lnx[i-1])
    
    b = (n*sum(power) - sum(count)*sum(lnx)) / (n*sum(lnxq) - sum(lnx)*sum(lnx))
    a = (sum(count) - b * sum(lnx))/(n-1)
    
    for i in range(0, n-1):
        y.append(a + b*lnx[i])

    pylab.figure(figsize=(14, 8))
    pylab.plot(x, y, color='blue', marker = '.')
    pylab.scatter(x, count, color='red', marker = '.')
    pylab.show()


if __name__ == "__main__":
    print("Проверка следствия теоремы Брауэра")
    print_graph(int(input("Введите N: ")), splitting)
# Out:
# Проверка следствия теоремы Брауэра
# Введите N: 201

# %% [markdown]
# **Вывод:**
#
# *На основе графика можно сделать вывод, что функция $l(n),\, n=1..200$ аппроксимируется логарифмической кривой. Это подтверждает следствие 1 теоремы Брауэра: $\lim\limits_{x\to\infty} \cfrac{l(n)}{\lambda(n)} = 1$, то есть $l(n)$ и $\lambda(n)$ эквивалентны на бесконечности. С увеличением $n$ длина минимальной аддитивной цепочки $l(n)$ будет увеличиваться как логарифмическая функция.*

# %% [markdown]
# ### Проверка гипотезы Шольца–Брауэра.
#
# Гипотеза Шольца–Брауэра проверена для $1 < n \leqslant 10$ на алгоритме дробления вектора индексов:

# %%
for i in range(2, 11):
    a = "n = " + str(i) + ":\t" + str(len(splitting(2**i-1))) + " <= " + str(len(splitting(i))+i-1)
    print(a)
# Out:
# n = 2:	3 <= 3
# n = 3:	5 <= 5
# n = 4:	6 <= 6
# n = 5:	8 <= 8
# n = 6:	9 <= 9
# n = 7:	11 <= 11
# n = 8:	11 <= 11
# n = 9:	13 <= 13
# n = 10:	14 <= 14

# %% [markdown]
# *Результаты провекри гипотезы Шольца-Брауэра:*
#
# |n    |$l^*(2n−1)$|$l^*(n)+n−1$|
# |:---:|:---------:|:----------:|
# |2    |3          |3           |
# |3    |5          |5           |
# |4    |6          |6           |
# |5    |8          |8           |
# |6    |9          |9           |
# |7    |11         |11          |
# |8    |11         |11          |
# |9    |13         |13          |
# |10   |14         |14          |
#
# **Вывод:**
#
# *На основе таблицы можно сделать вывод, что для $1 < n \leq 10$ гипотеза Шольца-Брауэра справедлива.*

# %% [markdown]
# ## Выводы
# В ходе выполнения практической работы:
# 1. были сформированы представления о аддитивных цепочках;
# 2. были изучены и реализованы с использованием систем компьютерной алгебры алгоритмы для нахождения минимальных аддитивных цепочек для заданного числа:
#     - бинарный метод
#     - метод множителей
#     - алгоритм Брауэра
#     - алгоритм дробления вектора индексов
# 3. было проверено следствие 1 теоремы Брауэра: $\lim\limits_{x\to\infty} \cfrac{l(n)}{\lambda(n)} = 1$;
# 4. была проверена гипотеза Шольца-Брауэра: $l^*(2^n-1)\leqslant l^*(n)+n-1$ для $1 < n \leq 10$.
#
# Было выяснено, что при увеличении  k  в алгоритме Брауэра длина аддитивной цепочки увеличивается, следовательно увеличивается и расхождение с минимальной длиной аддитивной цепочки. Алгоритм дробления вектора индексов даёт аддитивную цепочку минимальной длины, но при этом вычисления занимают много времени. При степенях $n = 2^k-1, k \in N$ метод множителей оказывается эффеткивнее бинарного метода. При степенях $n = 2^k+1, k = 5,6,...$ бинарный метод оказывается эффективнее. В остальных случаях оба метода выполняются за одно и то же число операций или метод множителей выполняется быстрее, но не значительно.
